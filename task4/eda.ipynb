# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read data

df = pd.read_csv('drive/MyDrive/globalterrorismdb.csv', encoding='ISO-8859-1')

df.head()
# Out:
# <ipython-input-4-e80ae95a0698>:4: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('drive/MyDrive/globalterrorismdb.csv', encoding='ISO-8859-1')
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# ...

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
# Drop all rows with NaN values in any column
df = df.dropna(axis = 1)

# Display the cleaned DataFrame
df.head()
# Out:
#         eventid  iyear  imonth  iday  extended  country         country_txt  \
# 0  197000000001   1970       7     2         0       58  Dominican Republic
# 1  197000000002   1970       0     0         0      130              Mexico
# 2  197001000001   1970       1     0         0      160         Philippines
# 3  197001000002   1970       1     0         0       78              Greece
# 4  197001000003   1970       1     0         0      101               Japan
#
#    region                   region_txt  vicinity  ...  \
# 0       2  Central America & Caribbean         0  ...
# 1       1                North America         0  ...
# 2       5               Southeast Asia         0  ...
# 3       8               Western Europe         0  ...
# 4       4                    East Asia         0  ...
#
#                                 gname  individual  weaptype1  weaptype1_txt  \
# 0                              MANO-D           0         13        Unknown
# ...

# %%
df.shape
# Out:
# (181691, 29)

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'extended', 'country',
#        'country_txt', 'region', 'region_txt', 'vicinity', 'crit1', 'crit2',
#        'crit3', 'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'targtype1', 'targtype1_txt', 'gname', 'individual', 'weaptype1',
#        'weaptype1_txt', 'property', 'dbsource', 'INT_LOG', 'INT_IDEO',
#        'INT_MISC', 'INT_ANY'],
#       dtype='object')

# %%
print(df.isnull().sum())
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# extended           0
# country            0
# country_txt        0
# region             0
# region_txt         0
# vicinity           0
# crit1              0
# crit2              0
# crit3              0
# success            0
# suicide            0
# attacktype1        0
# attacktype1_txt    0
# targtype1          0
# targtype1_txt      0
# gname              0
# individual         0
# weaptype1          0
# weaptype1_txt      0
# property           0
# dbsource           0
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 29 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   eventid          181691 non-null  int64
#  1   iyear            181691 non-null  int64
#  2   imonth           181691 non-null  int64
#  3   iday             181691 non-null  int64
#  4   extended         181691 non-null  int64
#  5   country          181691 non-null  int64
#  6   country_txt      181691 non-null  object
#  7   region           181691 non-null  int64
#  8   region_txt       181691 non-null  object
#  9   vicinity         181691 non-null  int64
#  10  crit1            181691 non-null  int64
#  11  crit2            181691 non-null  int64
#  12  crit3            181691 non-null  int64
#  13  success          181691 non-null  int64
#  14  suicide          181691 non-null  int64
#  15  attacktype1      181691 non-null  int64
# ...

# %%
# Incidents by country
country_counts = df['country_txt'].value_counts().head(20)  # Top 20 countries
plt.figure(figsize=(15, 8))
country_counts.plot(kind='bar')
plt.title('Top 20 Countries with Most Terrorism Incidents')
plt.xlabel('Country')
plt.ylabel('Number of Incidents')
plt.xticks(rotation=90)
plt.show()

# Incidents by region
region_counts = df['region_txt'].value_counts()
plt.figure(figsize=(12, 6))
region_counts.plot(kind='bar')
plt.title('Number of Terrorism Incidents by Region')
plt.xlabel('Region')
plt.ylabel('Number of Incidents')
plt.xticks(rotation=90)
plt.show()

# %%
attack_counts = df['attacktype1_txt'].value_counts()
plt.figure(figsize=(12, 6))
attack_counts.plot(kind='bar')
plt.title('Types of Terrorism Attacks')
plt.xlabel('Attack Type')
plt.ylabel('Number of Incidents')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
df.groupby('iyear').size().plot()
plt.title('Number of Terrorism Incidents Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Incidents')
plt.grid(True)
plt.show()

# %%
success_counts = df['success'].value_counts()
plt.figure(figsize=(6, 6))
success_counts.plot(kind='pie', autopct='%1.1f%%')
plt.title('Success of Terrorism Incidents')
plt.show()

suicide_counts = df['suicide'].value_counts()
plt.figure(figsize=(6, 6))
suicide_counts.plot(kind='pie', autopct='%1.1f%%')
plt.title('Suicide Attacks')
plt.show()

# %%
# Example: Correlation matrix
correlation_matrix = df[['success', 'suicide', 'property']].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
pivot_table = df.pivot_table(index='iyear', columns='region_txt', values='eventid', aggfunc='count', fill_value=0)
plt.figure(figsize=(14, 8))
sns.heatmap(pivot_table, cmap='YlGnBu', annot=True)
plt.title('Heatmap of Terrorism Incidents by Region and Year')
plt.show()
